# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# c:\Users\diego\OneDrive\Documentos\GitHub\data_analytics_zhaw\Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3435, 265)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\core\frame.py:1136, in _repr_html_(self)
#    1134 # more generally, whatever we allow in NDArrayBackedExtensionBlock
#    1135 arr = cast("np.ndarray | DatetimeArray | TimedeltaArray | PeriodArray", arr)
# -> 1136 return arr.T
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\format.py:1108, in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1079 def format_array(
#    1080     values: ArrayLike,
#    1081     formatter: Callable | None,
#    (...)
#    1090     fallback_formatter: Callable | None = None,
#    1091 ) -> list[str]:
#    1092     """
#    1093     Format an array for printing.
#    1094
#    1095     Parameters
#    1096     ----------
#    1097     values : np.ndarray or ExtensionArray
#    1098     formatter
#    1099     float_format
#    1100     na_rep
#    1101     digits
#    1102     space
#    1103     justify
#    1104     decimal
#    1105     leading_space : bool, optional, default True
#    1106         Whether the array should be formatted with a leading space.
#    1107         When an array as a column of a Series or DataFrame, we do want
# -> 1108         the leading space to pad between columns.
#    1109
#    1110         When formatting an Index subclass
#    1111         (e.g. IntervalIndex._get_values_for_csv), we don't want the
#    1112         leading space since it should be left-aligned.
#    1113     fallback_formatter
#    1114
#    1115     Returns
#    1116     -------
#    1117     List[str]
#    1118     """
#    1119     fmt_klass: type[_GenericArrayFormatter]
#    1120     if lib.is_np_dtype(values.dtype, "M"):
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\html.py:88, in HTMLFormatter.to_string(self)
#      87 def to_string(self) -> str:
# ---> 88     lines = self.render()
#      89     if any(isinstance(x, str) for x in lines):
#      90         lines = [str(x) for x in lines]
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\html.py:644, in NotebookFormatter.render(self)
#     642 self.write("<div>")
#     643 self.write_style()
# --> 644 super().render()
#     645 self.write("</div>")
#     646 return self.elements
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\html.py:94, in HTMLFormatter.render(self)
#      93 def render(self) -> list[str]:
# ---> 94     self._write_table()
#      96     if self.should_show_dimensions:
#      97         by = chr(215)  # ×  # noqa: RUF003
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\html.py:267, in HTMLFormatter._write_table(self, indent)
#     261 self.write(
#     262     f'<table{border_attr} class="{" ".join(_classes)}"{id_section}>',
#     263     indent,
#     264 )
#     266 if self.fmt.header or self.show_row_idx_names:
# --> 267     self._write_header(indent + self.indent_delta)
#     269 self._write_body(indent + self.indent_delta)
#     271 self.write("</table>", indent)
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\html.py:403, in HTMLFormatter._write_header(self, indent)
#     400 self.write("<thead>", indent)
#     402 if self.fmt.header:
# --> 403     self._write_col_header(indent + self.indent_delta)
#     405 if self.show_row_idx_names:
#     406     self._write_row_header(indent + self.indent_delta)
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\html.py:383, in HTMLFormatter._write_col_header(self, indent)
#     381     else:
#     382         row.append("")
# --> 383 row.extend(self._get_columns_formatted_values())
#     384 align = self.fmt.justify
#     386 if is_truncated_horizontally:
#
# File c:\Users\diego\Python310\lib\site-packages\pandas\io\formats\html.py:611, in NotebookFormatter._get_columns_formatted_values(self)
#     609 def _get_columns_formatted_values(self) -> list[str]:
#     610     # only reached with non-Multi Index
# --> 611     return self.columns._format_flat(include_name=False)
#
# AttributeError: 'Index' object has no attribute '_format_flat'
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:organic tags.diet:seafood tags.brand:website  \
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.currency:XBT tags.payment:lightning tags.payment:lightning_contactless  \
# 0               NaN                    NaN                                NaN
# 1               NaN                    NaN                                NaN
# 2               NaN                    NaN                                NaN
# 3               NaN                    NaN                                NaN
# 4               NaN                    NaN                                NaN
#
#   tags.payment:onchain
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 265 columns]

# %%
print(query)
# Out:
#         [out:json];
#         area["ISO3166-1"="CH"][admin_level=2];
#         node ["shop"="supermarket"](area);
#         out;

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1147abe998afb4df17bf54ec5c2678c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1147abe998afb4df17bf54ec5c2678c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1147abe998afb4df17bf54ec5c2678c = L.map(
#                 &quot;map_b1147abe998afb4df17bf54ec5c2678c&quot;,
#                 {
#                     center: [47.00765045569071, 7.993251455690703],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b1147abe998afb4df17bf54ec5c2678c);
#
#
#
#
#
#             var tile_layer_1d0eccede791121d0bdc200d49b2941d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1d0eccede791121d0bdc200d49b2941d.addTo(map_b1147abe998afb4df17bf54ec5c2678c);
#
#
#             var marker_c1658c938677a3ae03ad0710d791255e = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_b1147abe998afb4df17bf54ec5c2678c);
#
#
#         var popup_dab2c3d8c5777a4a7d7a248e309757f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ade69471d593225d0567d73feb0e4ac0 = $(`&lt;div id=&quot;html_ade69471d593225d0567d73feb0e4ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_dab2c3d8c5777a4a7d7a248e309757f1.setContent(html_ade69471d593225d0567d73feb0e4ac0);
#
#
#
#         marker_c1658c938677a3ae03ad0710d791255e.bindPopup(popup_dab2c3d8c5777a4a7d7a248e309757f1)
#         ;
#
#
#
#
#             var marker_2d6b7d50bbd50162d39365d6998e7e6f = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_b1147abe998afb4df17bf54ec5c2678c);
#
#
#         var popup_b5ac366957815f0089f0ab2919cd8579 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4841a8f7e00cc9c2e430e52ba09c0239 = $(`&lt;div id=&quot;html_4841a8f7e00cc9c2e430e52ba09c0239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_b5ac366957815f0089f0ab2919cd8579.setContent(html_4841a8f7e00cc9c2e430e52ba09c0239);
#
#
#
#         marker_2d6b7d50bbd50162d39365d6998e7e6f.bindPopup(popup_b5ac366957815f0089f0ab2919cd8579)
#         ;
#
#
#
#
#             var marker_133c061afc7aa0935529a9efb0b8b271 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_b1147abe998afb4df17bf54ec5c2678c);
#
#
#         var popup_3d079d6508f1177286a8a2ffff863af4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f3fa0f07e26ffcd6a70c605d70d203e = $(`&lt;div id=&quot;html_4f3fa0f07e26ffcd6a70c605d70d203e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_3d079d6508f1177286a8a2ffff863af4.setContent(html_4f3fa0f07e26ffcd6a70c605d70d203e);
#
#
#
#         marker_133c061afc7aa0935529a9efb0b8b271.bindPopup(popup_3d079d6508f1177286a8a2ffff863af4)
#         ;
#
#
#
#
#             var marker_b714f879af1095572bd37b1a31ee7752 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_b1147abe998afb4df17bf54ec5c2678c);
#
#
#         var popup_04cba26217e42ff63c28bc2e257bfe01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50f377d0157badba4d4810c529764e7c = $(`&lt;div id=&quot;html_50f377d0157badba4d4810c529764e7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_04cba26217e42ff63c28bc2e257bfe01.setContent(html_50f377d0157badba4d4810c529764e7c);
#
#
#
#         marker_b714f879af1095572bd37b1a31ee7752.bindPopup(popup_04cba26217e42ff63c28bc2e257bfe01)
#         ;
#
#
#
#
#             var marker_624fa67d59866365f30ad5db750b8525 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_b1147abe998afb4df17bf54ec5c2678c);
#
#
#         var popup_00ea50444ec7e880ddf2ef4c82ecab28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4812bcd454d2f42303167c3ccaf2526 = $(`&lt;div id=&quot;html_a4812bcd454d2f42303167c3ccaf2526&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_00ea50444ec7e880ddf2ef4c82ecab28.setContent(html_a4812bcd454d2f42303167c3ccaf2526);
#
#
#
#         marker_624fa67d59866365f30ad5db750b8525.bindPopup(popup_00ea50444ec7e880ddf2ef4c82ecab28)
#         ;
#
#
#
#
#             var marker_186dc8042b1064ed7d40aa8d4b87cc5a = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2024-09-18 14:39:34
# Python Version: 3.10.5
# -----------------------------------
